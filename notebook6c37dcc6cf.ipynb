# %% [markdown]
# ### 1. Loading the dataset

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/ted-talks/data.csv')

df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df.tail()
# Out:
#                                 title            author           date  \
# 5435  The best stats you've ever seen      Hans Rosling  February 2006
# 5436      Do schools kill creativity?  Sir Ken Robinson  February 2006
# 5437              Greening the ghetto     Majora Carter  February 2006
# 5438                 Simplicity sells       David Pogue  February 2006
# 5439      Averting the climate crisis           Al Gore  February 2006
#
#          views    likes                                               link
# 5435  15000000   458000  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  72000000  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437   2900000    88000  https://ted.com/talks/majora_carter_greening_t...
# 5438   2000000    60000  https://ted.com/talks/david_pogue_simplicity_s...
# 5439   3600000   109000  https://ted.com/talks/al_gore_averting_the_cli...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
arr = np.array(df['views'])

print('----- Views Analysis -----')
print('Minimun : ', np.min(arr))
print('Maximum : ', np.max(arr))
print('Total   : ', np.sum(arr))
print('Average : ', int(np.mean(arr)))
print('--------------------------')
# Out:
# ----- Views Analysis -----
# Minimun :  532
# Maximum :  72000000
# Total   :  11214973211
# Average :  2061575
# --------------------------

# %%
arr = np.array(df['likes'])

print('----- Likes Analysis -----')
print('Minimun : ', np.min(arr))
print('Maximum : ', np.max(arr))
print('Total   : ', np.sum(arr))
print('Average : ', int(np.mean(arr)))
print('--------------------------')
# Out:
# ----- Likes Analysis -----
# Minimun :  15
# Maximum :  2100000
# Total   :  340585435
# Average :  62607
# --------------------------

# %%
72000000
# Out:
# 72000000

# %%
df[df['views'] == 72000000]
# Out:
#                             title            author           date     views  \
# 5436  Do schools kill creativity?  Sir Ken Robinson  February 2006  72000000
#
#         likes                                               link
# 5436  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...

# %%
df[df['views'] > 50000000]
# Out:
#                                            title            author  \
# 2958  Inside the mind of a master procrastinator         Tim Urban
# 4084    Your body language may shape who you are         Amy Cuddy
# 4605                  The power of vulnerability       Brené Brown
# 4765            How great leaders inspire action       Simon Sinek
# 5436                 Do schools kill creativity?  Sir Ken Robinson
#
#                 date     views    likes  \
# 2958   February 2016  60000000  1800000
# 4084       June 2012  64000000  1900000
# 4605       June 2010  56000000  1700000
# 4765  September 2009  57000000  1700000
# 5436   February 2006  72000000  2100000
#
#                                                    link
# 2958  https://ted.com/talks/tim_urban_inside_the_min...
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...
# 4605  https://ted.com/talks/brene_brown_the_power_of...
# 4765  https://ted.com/talks/simon_sinek_how_great_le...
# ...

# %%
df['view_to_like_ratio'] = df['views']/df['likes']
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  view_to_like_ratio
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...           33.666667
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...           33.437500
# 2  https://ted.com/talks/martin_reeves_how_play_c...           34.333333
# ...

# %%
arr = np.array(df['view_to_like_ratio'])

print('----- Ratio Analysis -----')
print('Minimun : ', np.min(arr))
print('Maximum : ', np.max(arr))
print('Total   : ', np.sum(arr))
print('Average : ', int(np.mean(arr)))
print('--------------------------')
# Out:
# ----- Ratio Analysis -----
# Minimun :  30.3951367781155
# Maximum :  36.4
# Total   :  180146.4432242789
# Average :  33
# --------------------------

# %%
df[df['view_to_like_ratio'] < 31]
# Out:
#                                                   title  \
# 1071                          Three stories of Scotland
# 1112  The importance of queer allyship in the classroom
# 1462  Solar energy can help put power back in the ha...
# 1733                        A brie(f) history of cheese
# 1761  Cómo usar el arte de la fotografía para restau...
# 2247          How we'll predict the next refugee crisis
# 2248  8 steps to understanding information (and mayb...
# 2491              There's more to life than being happy
# 2558  Why you should define your fears instead of yo...
# 2918                          Why do cats act so weird?
# 3137  Imagining a new future for health systems in A...
#
#                       author           date     views   likes  \
# 1071     Mackenzie Dalrymple      July 2019     11000     359
# 1112            Coby Everton  November 2019     10000     329
# 1462            Scott Nguyen     April 2019     10000     326
# ...
